# %% [markdown]
# # **COVID-19 TF-IDF and BM25 Based Information Retrieval System**

# %% [markdown]
# We break this task down into a few steps:
#
#     1. Extract: here we extract the data from our dataset
#
#     2. Organize: our organize step allows us to create a dictionary where we store our information of interest, then we generate a new dictionary where we store our inverted indices based off of keywords that we find for each document
#
#     3. Retrieve: this step is where we run BM25 and generate our list of sorted results

# %% [markdown]
# ***

# %% [markdown]
# ### Libraries that we use

# %%
#libraries for getting data and extracting
import os
import urllib.request
import tarfile
import json
import pandas as pd
import numpy as np
from tqdm import tqdm


#libraries for text preprocessing
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
nltk.download('wordnet') 
from nltk.stem.wordnet import WordNetLemmatizer

#libraries for keyword extraction with tf-idf
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import coo_matrix

#libraries for reading and writing files
import pickle

#libraries for BM25
# !pip install rank_bm25
from rank_bm25 import BM25Okapi
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rank_bm25) (1.21.6)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2

# %% [markdown]
# ***

# %% [markdown]
# #**getData()** <br>
# Function to fetch and extract files <br>
# Note: That these files here are extremely huge, therefore when calling these function, it will be taking time.

# %%
def getData():
    urls = ['https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-03-27/comm_use_subset.tar.gz', 'https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-03-27/noncomm_use_subset.tar.gz', 'https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-03-27/custom_license.tar.gz', 'https://ai2-semanticscholar-cord-19.s3-us-west-2.amazonaws.com/2020-03-27/biorxiv_medrxiv.tar.gz']

    # Create data directory
    try:
        os.mkdir('./data')
        print('Directory created')
    except FileExistsError:
        print('Directory already exists')

    #Download all files
    for i in range(len(urls)):
        urllib.request.urlretrieve(urls[i], './data/file'+str(i)+'.tar.gz')
        print('Downloaded file '+str(i+1)+'/'+str(len(urls)))
        tar = tarfile.open('./data/file'+str(i)+'.tar.gz')
        tar.extractall('./data')
        tar.close()
        print('Extracted file '+str(i+1)+'/'+str(len(urls)))
        os.remove('./data/file'+str(i)+'.tar.gz')

# %% [markdown]
# #**preprocess()** <br>
# Function to Preproccessing text

# %%
def preprocess(text):
    #define stopwords
    stop_words = set(stopwords.words("english"))
    #Remove punctuations
    text = re.sub('[^a-zA-Z]', ' ', text)
    #Convert to lowercase
    text = text.lower()
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    ##Convert to list from string
    text = text.split()
    ##Stemming
    ps=PorterStemmer()
    text = [ps.stem(word) for word in text if not word in stop_words]
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  stop_words] 
    text = " ".join(text) 
    
    return text

# %% [markdown]
# #**extract()** <br>
# Since our data is huge, it is in compressed form once we download it, hence we need to extract and feed it into a dataframe

# %%
def extract():
    #create our collection locally in the data folder
    
    #creating our initial datastructure
    x = {'paper_id':[], 'title':[], 'abstract': []}
    
    #Iterate through all files in the data directory
    for subdir, dirs, files in os.walk('./data'):
        for file in tqdm(files):
            with open(os.path.join(subdir, file)) as f:
                data = json.load(f)
                
               #Append paper ID to list
                x['paper_id'].append(data['paper_id'])
               #Append article title to list & preprocess the text
                x['title'].append((data['metadata']['title']))
                
                #Append abstract text content values only to abstract list & preprocess the text
                abstract = ""
                for paragraph in data['abstract']:
                    abstract += paragraph['text']
                    abstract += '\n'
                #if json file no abstract in file, set the body text as the abstract (happens rarely, but often enough that this edge case matters)
                if abstract == "": 
                    for paragraph in data['body_text']:
                        abstract += paragraph['text']
                        abstract += '\n'
                x['abstract'].append(preprocess(abstract))
                
    #Create Pandas dataframe & write to pickle file
    df = pd.DataFrame.from_dict(x, orient='index')
    df = df.transpose()
    pickle.dump( df, open( "full_data_processed_FINAL.p", "wb" ) )
    return df

# %% [markdown]
# ***

# %% [markdown]
# #**organize()** <br>
# ####sort_matrix() - auxillary function for sorting tf_idf in descending order<br>
# > input: tf_idf matrix
#
# > output: tf_idf items sorted in descending order, so things with highest scores at the top

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

# %% [markdown]
# #### get top n words with highest tf-idf scores
# >input:
#
#         1. feature_names = vocabulary
#         2. sorted_items = tf-idf vectors sorted in descending order
#         3. topN = # of keywords you would like extract from text
#
# >output: dictionary of topN # words with highest tf-idf scores in the text (key) and their corresponding tf-idf scores (value)
#
# Gets keyword names and their tf-idf scores of topN items

# %%
def extract_topn_from_vector(feature_names, sorted_items, topN):
    #use only topn items from vector
    sorted_items = sorted_items[:topN]
 
    score_vals = []
    feature_vals = []
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    #create a tuples of feature,score
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    return results

# %% [markdown]
# #### getting abstract keywords
# > input:
#
#         1. entry = row in the article dataframe, which represents one article
#         2. cv = CountVectorizer, from sklearn.feature_extraction.text
#         3. X = vector that represents the CountVectorizer fit to the corpus
#         4. tfidf_transformer = object that holds our tf_idf data -- again, fit to our corpus
#         5. feature_names = vocabulary
#         6. topN = # of keywords we'd like to extract from the abstract
#
# > output: the topN keywords from the abstract
#
# Extracts the topN keywords from the abstract

# %%
def getAbstractKeywords(entry, cv, X, tfidf_transformer, feature_names, topN):
    abstract = entry['abstract']
    
    #first check that abstract is full
    if type(abstract) == float:
        return []
 
    #generate tf-idf for the given document
    tf_idf_vector=tfidf_transformer.transform(cv.transform([abstract])) 
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())
    #extract only the topN # items
    keywords_dict=extract_topn_from_vector(feature_names,sorted_items,topN)
    #just want words themselves, so only need keys of the dictionary
    keywords = list(keywords_dict.keys()) 
     
    return keywords

# %% [markdown]
# #### getting title keywords
# >input: entry = row in the article dataframe, which represents one article
#
# >output: list of all the words in the title
#
# Assumed that if a word is in the title of the article, it must be important to the article and treated like a keyword.
# Thus, this method just extracts all the words from the (already processed) title.

# %%
def getTitleKeywords(entry):
    title = entry['title']  
    title = preprocess(title)
    #first check that the title of that entry is full
    if type(title) == float:
        return []
    
    keywords_title = title.split(' ')
    return keywords_title

# %% [markdown]
# #### getting final keywords
# >input:
#
#         1. entry = row in the article dataframe, which represents one article
#         2. cv = CountVectorizer, from sklearn.feature_extraction.text
#         3. X = vector that represents the CountVectorizer fit to the corpus
#         4. tfidf_transformer = object that holds our tf_idf data -- again, fit to our corpus
#         5. feature_names = vocabulary
#         6. topN = # of keywords we'd like to extract from the abstract
# > output: list of *all* keywords for an article -- extracted from both title and abstract!
#
# Calls getTitleKeywords() and getAbstractKeywords() and concatenates the two lists, resulting in a final list of keywords

# %%
def getFinalKeywords(entry, cv, X, tfidf_trans, feature_names, topN):
    #get keywords from abstract and title
    fromAbstract = getAbstractKeywords(entry, cv, X, tfidf_trans, feature_names, topN)
    fromTitle = getTitleKeywords(entry)
    #concatenate two lists
    finalKeywords = fromAbstract + fromTitle
    #convert to set and then back to list to ensure there are no duplicates in list
    final_no_duplicates = list(set(finalKeywords))
    return final_no_duplicates

# %% [markdown]
# #### getting corpus
# >input: dataframe that contains the 1) paper_id 2) abstract and 3) article for every article. All text is processed.
#
# >output: a list that contains every abstracts in the in the article dataframe
#
# Creating a corpus, which is a necessary input to our tf_idf step.

# %%
def getCorpus(articlesDf):
    #creating a new dataframe, abstractDf, of just the abstracts, so that we don't modify the original dataframe, articlesDf
    abstractDf = pd.DataFrame(columns = ['abstract'])
    #filling abstractDf with the abstract column from articlesDf
    abstractDf['abstract'] = articlesDf['abstract']
    #converting column of dataframe to a list
    corpus = abstractDf['abstract'].to_list()
    return corpus

# %% [markdown]
# #### adding keywords
#
# >input:
#
#         1. df = dataframe that contains the 1) paper_id 2) title and 3) abstract for every article. All text is processed
#         2. topN = # of keywords we'd like to extract from the abstract
#         3. makeFile = boolean, whether you'd like this method to make a pickle file of the output dataframe
#         4. fileName = what the user would like to name the pickle file
#
# > output: pandas dataframe that contains the
#
#         1. paper_id
#         2. title
#         3. abstract and
#         4. keywords associated with every article

# %%
def addKeywords(df, topN, makeFile, fileName):
    #defining stopwords
    stop_words = set(stopwords.words("english"))

    #creating following variables that are needed for keyword extract from abstract, using tf-idf methodology,
    #all input in getFinalKewords method
    corpus = getCorpus(df)
    cv=CountVectorizer(max_df=0.8,stop_words=stop_words, max_features=1000, ngram_range=(1,1))    
    X=cv.fit_transform(corpus)
    tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
    tfidf_transformer.fit(X)
    feature_names=cv.get_feature_names()
    
    #adding keywords article to dataframe
    df = df.reindex(columns = ['paper_id', 'title', 'abstract','keywords'])                
    #getting keywords for each entry in article dataframe -- using apply to be more efficient
    df['keywords'] = df.apply(lambda row: getFinalKeywords(row, cv, X, tfidf_transformer, feature_names, topN), axis=1)

    #make pickle file depending on user input
    if makeFile == True:
        pickle.dump( df, open( fileName, "wb" ) )
    return df

# %% [markdown]
# #### creating inverted indices
#
# >input: pandas dataframe that contains the 1) paper_id 2) title 3)abstract and 4) keywords associated with every article
#
# >output: dictionary of inverted indices -- key = word that is a keyword; value = all articles' paper_id's that have word as a keyword
#
# Creating an inverted indices dictionary. Will use this when deciding which subset of articles to run our ranking/retrieving algorithm on.
# It is important that our output is a dictionary because it has constant look up time.

# %%
def createInvertedIndices(df):
    numEntries = df.shape[0]
    invertInd = {}
    
    for i in range (numEntries):
        entry = df.iloc[i]
        paper_id = entry['paper_id']    
        keywords = entry['keywords']
        for k in keywords:
            if k not in invertInd:
                invertInd[k] = []
                invertInd[k].append(paper_id)
            else:
                invertInd[k].append(paper_id)
    return invertInd

# %% [markdown]
# #### organize step

# %%
def organize():
    df_without_keywords = pickle.load(open("full_data_processed_FINAL.p", "rb"))
    df_with_keywords = addKeywords(df_without_keywords, 10, False, "full_data_withKeywords_FINAL.p")
    invertedIndices = createInvertedIndices(df_with_keywords)
    pickle.dump( invertedIndices, open( "invertedIndices_FINAL.p", "wb" ) )

# %% [markdown]
# ***

# %%
getData()
extract()

df_without_keywords = pickle.load(open("full_data_processed_FINAL.p", "rb"))
df_with_keywords = addKeywords(df_without_keywords, 10, False, "full_data_withKeywords_FINAL.p")
display(df_without_keywords)
display(df_with_keywords)
# Out:
# Directory created
# Downloaded file 1/4
# Extracted file 1/4
# Downloaded file 2/4
# Extracted file 2/4
# Downloaded file 3/4
# Extracted file 3/4
# Downloaded file 4/4
# Extracted file 4/4
# 0it [00:00, ?it/s]
# 100%|██████████| 2350/2350 [01:00<00:00, 38.63it/s]
# 100%|██████████| 1053/1053 [00:11<00:00, 91.86it/s]
# 100%|██████████| 9315/9315 [01:50<00:00, 84.22it/s]
# 100%|██████████| 20657/20657 [13:38<00:00, 25.24it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                        paper_id  \
# 0      a6eb398b44cfa0686f072f5cdbd07372587f0ed0
# 1      4b3d6bca8bfe315d03331cba07299570e2ce7fad
# 2      bca792def155d06e618f4fe78f6f4178ed5e1b69
# 3      eb136cf532bef626a3f5d4d32fef88e7b43ef3fb
# 4      41deae1169912161f5195d978626aa2ca1898994
# ...                                         ...
# 33370  88fda71a3c0b92de587a797b3490442822bac919
# 33371  5b7a901d661496d6b94f4ba03f835ccc47cae43d
# 33372  c37def44c43df167c79e4376d9b3961d382f4186
# 33373  f39f714b92770a09beeef5caf31330e5296221a9
# 33374  9d9c2e95d079dc7b3c17b8332fea83aa41766749
#
#                                                    title  \
# 0
# 1      At the crossroads of autophagy and infection: ...
# 2
# 3      Isolation, Characterization, and Expression of...
# 4      Veterinary Science pISSN 1229-845X, eISSN 1976...
# ...                                                  ...
# 33370  Detection of bovine coronavirus using a TaqMan...
# 33371             Cryptosporidiosis in small ruminants ଝ
# 33372  Production of Ebola virus-like particles in Dr...
# 33373  Molecular Detection of Multiple Respiratory Vi...
# 33374
#
#                                                 abstract
# 0      medic staff lack clinic handl treat infect pat...
# 1      macroautophagi autophagi involv format doubl m...
# 2      case seri summari case seri discus novel chara...
# 3      golgi mannosidas ii g cnac transferas depend m...
# 4      vaccin effect method prevent infect control sp...
# ...                                                  ...
# 33370  real time revers transcriptas polymeras chain ...
# 33371  cryptosporidiosi infect caus protozoan parasit...
# 33372  studi gener recombin viru like particl vlp fam...
# 33373  respiratori infect common human ill worldwid c...
# 33374  multipl myeloma uncommon neoplasm bone marrow ...
#
# [33375 rows x 3 columns]
#                                        paper_id  \
# 0      a6eb398b44cfa0686f072f5cdbd07372587f0ed0
# 1      4b3d6bca8bfe315d03331cba07299570e2ce7fad
# 2      bca792def155d06e618f4fe78f6f4178ed5e1b69
# 3      eb136cf532bef626a3f5d4d32fef88e7b43ef3fb
# 4      41deae1169912161f5195d978626aa2ca1898994
# ...                                         ...
# 33370  88fda71a3c0b92de587a797b3490442822bac919
# 33371  5b7a901d661496d6b94f4ba03f835ccc47cae43d
# 33372  c37def44c43df167c79e4376d9b3961d382f4186
# 33373  f39f714b92770a09beeef5caf31330e5296221a9
# 33374  9d9c2e95d079dc7b3c17b8332fea83aa41766749
#
#                                                    title  \
# 0
# 1      At the crossroads of autophagy and infection: ...
# 2
# 3      Isolation, Characterization, and Expression of...
# 4      Veterinary Science pISSN 1229-845X, eISSN 1976...
# ...                                                  ...
# 33370  Detection of bovine coronavirus using a TaqMan...
# 33371             Cryptosporidiosis in small ruminants ଝ
# 33372  Production of Ebola virus-like particles in Dr...
# 33373  Molecular Detection of Multiple Respiratory Vi...
# 33374
#
#                                                 abstract  \
# 0      medic staff lack clinic handl treat infect pat...
# 1      macroautophagi autophagi involv format doubl m...
# 2      case seri summari case seri discus novel chara...
# 3      golgi mannosidas ii g cnac transferas depend m...
# 4      vaccin effect method prevent infect control sp...
# ...                                                  ...
# 33370  real time revers transcriptas polymeras chain ...
# 33371  cryptosporidiosi infect caus protozoan parasit...
# 33372  studi gener recombin viru like particl vlp fam...
# 33373  respiratori infect common human ill worldwid c...
# 33374  multipl myeloma uncommon neoplasm bone marrow ...
#
#                                                 keywords
# 0      [lead, , maintain, public, routin, activ, heal...
# 1      [protein, et, al, complex, role, noncanon, cro...
# 2      [seri, novel, upper, , airway, case, sign, ide...
# 3      [complex, golgi, mannosidas, clone, encod, pat...
# 4      [protein, significantli, antibodi, influenza, ...
# ...                                                  ...
# 33370  [pcr, detect, use, bovin, taqman, cattl, time,...
# 33371  [especi, cryptosporidiosi, small, pre, speci, ...
# 33372  [protein, particl, schneider, recombin, like, ...
# 33373  [pcr, detect, use, reaction, virus, multipl, r...
# 33374  [protein, , multipl, cat, mg, case, serum, cel...
#
# [33375 rows x 4 columns]

# %% [markdown]
# ***

# %% [markdown]
# #**retrieve()**
# #### getting our subset of articles
# >input: query
#
# >output: a list of the potential articles that may be of interest, as they have some of the query terms as their keyword(s)
#
# Doing this step so we don't have to run our ranking algorithm, BM25, over all ~30,000 articles.

# %%
def getPotentialArticleSubset(query):
    #load in inverted indices
    invertedIndices = pickle.load(open("invertedIndices_FINAL.p", "rb"))
    
    #preprocess query and split into individual terms
    query = preprocess(query)
    queryTerms = query.split(' ')
    
    potentialArticles = []
    #concatenate list of potential articles by looping through potential articles for each word in query
    for word in queryTerms:
        if word in invertedIndices: #so if someone types in nonsensical query term that's not in invertedIndices, still won't break!
            someArticles = invertedIndices[word]
            potentialArticles = potentialArticles + someArticles
            
    #convert to set then back to list so there are no repeat articles
    potentialArticles = list(set(potentialArticles))
    return potentialArticles

# %% [markdown]
# #### bm25 method
#
# >input: list of articles, dictionary with all of the documents, weight of the title, weight of the abstract, and the query
#
# >output: list of ranked articles
#
# This is the main information retrieval method implementing Okapi BM25

# %%
def bm25(articles, df_dic, title_w, abstract_w, query):
    corpus_title = []
    corpus_abstract = []
    
    for article in articles:
        arr = df_dic.get(article)
        #title
        if type(arr[0]) != float:
            preprocessedTitle = preprocess(arr[0])
            corpus_title.append(preprocessedTitle)
        else:
            corpus_title.append(" ")
        
        #abstract
        if type(arr[1]) != float:
            preprocessedAbst = preprocess(arr[1])
            corpus_abstract.append(preprocessedAbst)
        else:
            corpus_abstract.append(" ")
            
    query = preprocess(query)
    
    tokenized_query = query.split(" ")
    
    tokenized_corpus_title = [doc.split(" ") for doc in corpus_title]
    tokenized_corpus_abstract = [doc.split(" ") for doc in corpus_abstract]
    
    #running bm25 on titles
    bm25_title = BM25Okapi(tokenized_corpus_title)
    doc_scores_titles = bm25_title.get_scores(tokenized_query)
    #weighting array
    doc_scores_titles = np.array(doc_scores_titles)
    doc_scores_titles = doc_scores_titles**title_w
    
    #running bm25 on abstracts
    bm25_abstract = BM25Okapi(tokenized_corpus_abstract)
    doc_scores_abstracts = bm25_abstract.get_scores(tokenized_query)
    #weighting
    doc_scores_abstracts = np.array(doc_scores_abstracts)
    doc_scores_abstracts = doc_scores_abstracts ** abstract_w
    
    #summing up the two different scores
    doc_scores = np.add(doc_scores_abstracts,doc_scores_titles)
    
    #creating a dictionary with the scores
    score_dict = dict(zip(articles, doc_scores))
    
    #creating list of ranked documents high to low
    doc_ranking = sorted(score_dict, key=score_dict.get, reverse = True)
    
    #get top 100
    doc_ranking = doc_ranking[0:100]
    
    for i in range(len(doc_ranking)):
        dic_entry = df_dic.get(doc_ranking[i])
        doc_ranking[i] = dic_entry[0]
    
    return doc_ranking

# %% [markdown]
# #### retrieval step

# %%
def retrieve(queries):
    #performing information retrieval
    df_without_keywords = pickle.load(open("full_data_processed_FINAL.p", "rb"))
    df_dic = df_without_keywords.set_index('paper_id').T.to_dict('list')
    results = []
    for q in queries:
        articles = getPotentialArticleSubset(q)
        result = bm25(articles,df_dic,1,2,q)
        results.append(result)

    #Output results
    for query in range(len(results)):
        for rank in range(len(results[query])):
            print(str(query+1)+'\t'+str(rank+1)+'\t'+str(results[query][rank]))

# %% [markdown]
# ***

# %% [markdown]
# # **Calling all required functions and final execution**

# %% [markdown]
# ##Here we give the query related to the information we need
# We have given origin, weather changes and immunity. <br>
# Top 100 articles are ranked  by BM25 rank for each query sorted. <br>
#
# *   First # signifies the # of query in the query list <br>
#
#   1.  for origin <br>
#   2. for weather changes <br>
#   3. for immunity <br>
# *   Second # signifies the article number <br>
#
# * Third field is the abstract of the query

# %%
getData()
extract()
organize()
q = ['coronavirus origin',
'coronavirus response to weather changes',
'coronavirus immunity']
retrieve(q)
# Out:
# Directory already exists
# Downloaded file 1/4
# Extracted file 1/4
# Downloaded file 2/4
# Extracted file 2/4
# Downloaded file 3/4
# Extracted file 3/4
# Downloaded file 4/4
# Extracted file 4/4
# 0it [00:00, ?it/s]
# 100%|██████████| 2350/2350 [00:59<00:00, 39.27it/s]
# 100%|██████████| 1053/1053 [00:11<00:00, 91.05it/s]
# 100%|██████████| 9315/9315 [01:53<00:00, 82.06it/s]
# 100%|██████████| 20657/20657 [13:44<00:00, 25.04it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 1	1	Insights into the cross-species evolution of 2019 novel coronavirus
# 1	2	Bat origin of human coronaviruses
# 1	3
# 1	4	Origin, Evolution, and Genotyping of Emergent Porcine Epidemic Diarrhea Virus Strains in the United States
# 1	5	The battle against SARS and MERS coronaviruses: Reservoirs and Animal Models
# 1	6	Newly emerged porcine enteric alphacoronavirus in southern China: Identification, origin and evolutionary history analysis
# 1	7	Molecular Evolution of Human Coronavirus Genomes
# 1	8	MOTS CLÉS
# 1	9	Bat origin of a new human coronavirus: there and back again
# 1	10	A review of studies on animal reservoirs of the SARS coronavirus
# 1	11	SARS-Coronavirus ancestor's foot-prints in South-East Asian bat colonies and the refuge theory
# 1	12	Testing the hypothesis of a recombinant origin of the SARS-associated coronavirus
# 1	13	ScienceDirect Focus on Middle East respiratory syndrome coronavirus (MERS-CoV)
# 1	14
# 1	15	Evidence of recombination in coronaviruses implicating pangolin origins of nCoV- 2019
# 1	16	Coronaviruses: emerging and re-emerging pathogens in humans and animals
# 1	17	Emergence of SARS-CoV-2 through Recombination and Strong Purifying Selection Short Title: Recombination and origin of SARS-CoV-2 One Sentence Summary: Extensive Recombination and Strong Purifying Selection among coronaviruses from different hosts facilitate the emergence of SARS-CoV-2
# 1	18	Recombination and Coronavirus Defective Interfering RNAs
# 1	19	COVID-19 infection: origin, transmission, and characteristics of human coronaviruses
# 1	20	A Bat-Derived Putative Cross-Family Recombinant Coronavirus with a Reovirus Gene a11111 OPEN ACCESS
# 1	21	Les infections à coronavirus humains
# 1	22	PCR sequencing of the spike genes of geographically and chronologically distinct human coronaviruses 229E
# 1	23	Genomic characterisation and epidemiology of 2019 novel coronavirus: implications for virus origins and receptor binding
# 1	24	Direct diagnosis of human respiratory coronaviruses 229E and OC43 by the polymerase chain reaction
# 1	25	Spike Protein Fusion Peptide and Feline Coronavirus Virulence
# 1	26	Genomic Analysis and Surveillance of the Coronavirus Dominant in Ducks in China
# 1	27	Evidence from the evolutionary analysis of nucleotide sequences for a recombinant history of SARS-CoV
# 1	28	Recombination in Avian Gamma-Coronavirus Infectious Bronchitis Virus
# 1	29	Biomedical Science Review SARS Virus: The Beginning of the Unraveling of a New Coronavirus
# 1	30	Complete genome sequence of bat coronavirus HKU2 from Chinese horseshoe bats revealed a much smaller spike gene with a different evolutionary lineage from the rest of the genome
# 1	31	Complete Genome Sequence of a Novel Swine Acute Diarrhea Syndrome Coronavirus, CH/FJWT/2018, Isolated in Fujian, China, in 2018
# 1	32	Identification and Characterization of a Novel Alpaca Respiratory Coronavirus Most Closely Related to the Human Coronavirus 229E
# 1	33	REPLICATION OF A BOVINE CORONAVIRUS IN ORGAN CULTURES OF FOETAL TRACHEA
# 1	34
# 1	35	Recombinant Canine Coronaviruses in Dogs, Europe
# 1	36	Human Coronavirus EMC Is Not the Same as Severe Acute Respiratory Syndrome Coronavirus
# 1	37	Discovery of Bat Coronaviruses through Surveillance and Probe Capture-Based Next-Generation Sequencing
# 1	38	Selection of and recombination between minor variants lead to the adaptation of an avian coronavirus to primate cells
# 1	39	A second, non-canonical RNA-dependent RNA polymerase in SARS Coronavirus
# 1	40	Middle East Respiratory Syndrome Coronavirus (MERS-CoV) origin and animal reservoir
# 1	41	Cryo-electron microscopy structure of the SADS-CoV spike glycoprotein 1 provides insights into an evolution of unique coronavirus spike proteins 2 3
# 1	42	Journal Pre-proof The SARS-CoV-2 outbreak: what we know The SARS-CoV-2 Outbreak: What We Know
# 1	43	Genomic characterization of the 2019 novel human-pathogenic coronavirus isolated from a patient with atypical pneumonia after visiting Wuhan
# 1	44	Outbreak 2019-nCoV (Wuhan virus), a novel Coronavirus: human-to-human transmission, travel-related cases, and vaccine readiness
# 1	45	Tropical Medicine and Infectious Disease Potential Intermediate Hosts for Coronavirus Transmission: No Evidence of Clade 2c Coronaviruses in Domestic Livestock from Ghana
# 1	46
# 1	47	SARS associated coronavirus has a recombinant polymerase and coronaviruses have a history of host-shifting
# 1	48	Detection of alpha-and betacoronaviruses in rodents from Yunnan, China
# 1	49	The aetiology, origins, and diagnosis of severe acute respiratory syndrome
# 1	50	Detection and full genome characterization of two beta CoV viruses related to Middle East respiratory syndrome from bats in Italy
# 1	51	Genetic diversity of a canine coronavirus detected in pups with diarrhoea in Italy
# 1	52	Discovery, diversity and evolution of novel coronaviruses sampled from rodents in China
# 1	53	The nucleocapsid protein of the SARS coronavirus is capable of self-association through a C-terminal 209 amino acid interaction domain q
# 1	54
# 1	55	Geographical structure of bat SARS-related coronaviruses
# 1	56	Biopolymeric nano/microspheres for selective and reversible adsorption of coronaviruses
# 1	57	Understanding the accessory viral proteins unique to the severe acute respiratory syndrome (SARS) coronavirus
# 1	58	Human-animal interactions and bat coronavirus spillover potential among rural residents in Southern China-NC-ND license (http://creativecommons.org/licenses/by-nc-nd/4.0/)
# 1	59	Structural Insights into the Interaction of Coronavirus Papain-Like Proteases and Interferon-Stimulated Gene Product 15 from Different Species
# 1	60	Detection of potentially novel paramyxovirus and coronavirus viral RNA in bats and rats in the Mekong Delta region of southern Viet Nam
# 1	61	Opinion Novel coronavirus: From discovery to clinical diagnostics
# 1	62	Molecular and phylogenetic analysis of bovine coronavirus based on the spike glycoprotein gene
# 1	63	Canine respiratory coronavirus employs caveolin-1-mediated pathway for internalization to HRT-18G cells
# 1	64	Discovery of a novel canine respiratory coronavirus support genetic recombination among betacoronavirus1
# 1	65
# 1	66	SARS-CoV-2 is sensitive to type I interferon pretreatment
# 1	67	Adaptation of human enteric coronavirus to growth in cell lines
# 1	68	Molecular characterization of a canine respiratory coronavirus strain detected in Italy ଝ
# 1	69	Epidemiology, Genetic Recombination, and Pathogenesis of Coronaviruses
# 1	70	Cryo-EM structures of HKU2 and SADS-CoV spike 1 glycoproteins and insights into coronavirus evolution 2 3 4
# 1	71	No credible evidence supporting claims of the laboratory engineering of SARS-CoV-2
# 1	72	Development of a Whole-Virus ELISA for Serological Evaluation of Domestic Livestock as Possible Hosts of Human Coronavirus NL63
# 1	73	X-ray Structure of Main Protease of the Novel Coronavirus SARS-CoV-2 Enables Design of a-Ketoamide Inhibitors
# 1	74	Cross-sectional survey of selected enteric viruses in Polish turkey flocks between 2008 and 2011
# 1	75	Enzyme-linked Immunosorbent Assay for the Detection of Porcine Epidemic Diarrhea Coronavirus Antibodies in Swine Sera
# 1	76	Article Bat Origins of MERS-CoV Supported by Bat Coronavirus HKU4 Usage of Human Receptor CD26
# 1	77	Functional analysis of the stem loop S3 and S4 structures in the coronavirus 3′UTR
# 1	78	New Alphacoronavirus in Mystacina tuberculata Bats, New Zealand
# 1	79	Identification of New Respiratory Viruses in the New Millennium
# 1	80	Genomic characterization and infectivity of a novel SARS-like coronavirus in Chinese bats
# 1	81	Memory T cell responses targeting the SARS coronavirus persist up to 11 years post-infection
# 1	82
# 1	83	Further Evidence for Bats as the Evolutionary Source of Middle East Respiratory Syndrome Coronavirus
# 1	84	Putative Receptor Binding Domain of Bat-Derived Coronavirus HKU9 Spike Protein: Evolution of Betacoronavirus Receptor Binding Motifs
# 1	85	Porcine epidemic diarrhea: A retrospect from Europe and matters of debate
# 1	86	Cell adhesion as a novel approach to determining the cellular binding motif on the severe acute respiratory syndrome coronavirus spike protein
# 1	87	Origin and Possible Genetic Recombination of the Middle East Respiratory Syndrome Coronavirus from the First Imported Case in China: Phylogenetics and Coalescence Analysis
# 1	88	Clinical Medicine Editorial Initial Cluster of Novel Coronavirus (2019-nCoV) Infections in Wuhan, China Is Consistent with Substantial Human-to-Human Transmission
# 1	89	Shared Common Ancestry of Rodent Alphacoronaviruses Sampled Globally
# 1	90	NEW RESPIRATORY VIRUS IN PEDIATRICS
# 1	91	Animal origins of SARS coronavirus: possible links with the international trade in small carnivores
# 1	92	MERS Coronavirus: An Emerging Zoonotic Virus
# 1	93	Emergence of the Middle East Respiratory Syndrome Coronavirus
# 1	94	Replication of MERS and SARS coronaviruses in bat cells offers insights to their ancestral origins
# 1	95	Perspectives on the epizootiology of feline enteric coronavirus and the pathogenesis of feline infectious peritonitis
# 1	96
# 1	97	Clinical Microbiology Middle Eastern Respiratory Syndrome Coronavirus (MERS-CoV)
# 1	98	Full-genome evolutionary analysis of the novel corona virus (2019-nCoV) rejects the hypothesis of emergence as a result of a recent recombination event
# 1	99	Immunogenicity of an adenoviral-based Middle East Respiratory Syndrome coronavirus vaccine in BALB/c mice
# 1	100	NOTE Feline coronavirus isolates from a part of Brazil: insights into molecular epidemiology and phylogeny inferred from the 7b gene
# 2	1	A case-crossover analysis of the impact of weather on primary cases of Middle East respiratory syndrome
# 2	2	Advice-giving in newspaper weather commentaries
# 2	3	Severe weather warnings predict fracture epidemics
# 2	4	SYSTEMATIC REVIEW Extreme water-related weather events and waterborne disease
# 2	5	Pathogen seasonality and links with weather in England and Wales: a big data time series analysis
# 2	6	Short Term Effects of Weather on Hand, Foot and Mouth Disease
# 2	7	Influence of extreme weather and meteorological anomalies on outbreaks of influenza A (H1N1)
# 2	8	Journal Pre-proof A conceptual model for the outbreak of Coronavirus disease 2019 (COVID-19) in Wuhan, China with individual reaction and governmental action
# 2	9	Climate Change and Health in Canada
# 2	10	Weather-Dependent Risk for Legionnaires' Disease, United States Legionella pneumophila [leʺjə-nelʹə nooʺmo-filʹə]
# 2	11	Impacts of Social and Economic Factors on the Transmission of Coronavirus Disease 2019 (COVID-19) in China *
# 2	12	Computational Statistics and Data Analysis Modeling respiratory illnesses with change point: A lesson from the SARS epidemic in Hong Kong Change point problem Multiple index model Non-parametric regression Public health Respiratory illness Severe acute respiratory syndrome (SARS)
# 2	13	Challenges in developing methods for quantifying the effects of weather and climate on water-associated diseases: A systematic review
# 2	14	China's adaptation to climate & urban climatic changes: A critical review
# 2	15	Impact of global warming on viral diseases: what is the evidence? This review comes from a themed issue on Pharmaceutical biotechnology Edited
# 2	16
# 2	17	Climate change and infectious diseases: What can we expect?
# 2	18	RAT CORONAVIRUS
# 2	19	Respiratory syncytial virus bronchiolitis, weather conditions and air pollution in an Italian urban area: An observational study
# 2	20
# 2	21	Num 1
# 2	22	One Health: Zoonoses in the Exotic Animal Practice KEYWORDS • Zoonoses • Exotic pets • Nontraditional pets • Wildlife • Disease prevention
# 2	23	Mapping Climate Change Vulnerabilities to Infectious Diseases in Europe
# 2	24
# 2	25	Bovine Coronavirus Associated Syndromes
# 2	26
# 2	27	Coronaviridae
# 2	28	Millennium Project The Millennium Project: the positive health implications of improved environmental sustainability
# 2	29
# 2	30	Title: Effects of weather-related social distancing on city-scale transmission of respiratory viruses (limit 96 characters)
# 2	31	Transportation and
# 2	32	Emerging and Re-emerging Pathogens and Diseases, and Health Consequences of a Changing Climate
# 2	33	Public Health Response Systems In-Action: Learning from Local Health Departments' Experiences with Acute and Emergency Incidents
# 2	34	Environmental Health, Planetary Boundaries and Limits to Growth
# 2	35	Stabilized coronavirus spikes are resistant to conformational changes induced by receptor recognition or proteolysis OPEN
# 2	36	PCR sequencing of the spike genes of geographically and chronologically distinct human coronaviruses 229E
# 2	37	Mechanisms of Coronavirus Cell Entry Mediated by the Viral Spike Protein
# 2	38	Characterization of amino acid substitutions in feline coronavirus 3C-like protease from a cat with feline infectious peritonitis treated with a protease inhibitor
# 2	39	Spike Protein Fusion Peptide and Feline Coronavirus Virulence
# 2	40	Fatal Enteritis Associated with Coronavirus Infection in Cats
# 2	41	Correspondence Submissions should be made via our electronic submission system at http://ees.elsevier.com/ thelancet
# 2	42	Molecular Modeling Evaluation of the Binding Effect of Ritonavir, Lopinavir and Darunavir to Severe Acute Respiratory Syndrome Coronavirus 2 Proteases
# 2	43	Structure of mouse coronavirus spike protein complexed with receptor reveals mechanism for viral entry
# 2	44
# 2	45
# 2	46	Comparative sequence analysis of full-length genome of FIPV at different tissue passage levels
# 2	47	A Massachusetts prototype like coronavirus isolated from wild peafowls is pathogenic to chickens
# 2	48	Evidence for RNA editing in the transcriptome of 2019 Novel Coronavirus
# 2	49	Canine Coronavirus Highly Pathogenic for Dogs
# 2	50	Caution: The clinical characteristics of COVID-19 patients at admission are changing
# 2	51	Quasispecies of bovine enteric and respiratory coronaviruses based on complete genome sequences and genetic changes after tissue culture adaptation
# 2	52	Analysis on the Clinical Characteristics of 36 Cases of Novel Coronavirus Pneumonia in Kunming
# 2	53	Emergence of a group 3 coronavirus through recombination
# 2	54	Altering SARS Coronavirus Frameshift Efficiency Affects Genomic and Subgenomic RNA Production
# 2	55	Systemic fatal type II coronavirus infection in a dog: Pathological findings and immunohistochemistry
# 2	56
# 2	57
# 2	58	Potent inhibition of feline coronaviruses with peptidyl compounds targeting coronavirus 3C-like protease
# 2	59	Prediction of New Coronavirus Infection Based on a Modified SEIR Model
# 2	60	Topographic Changes in SARS Coronavirus-infected Cells during Late Stages of Infection
# 2	61	Bat origin of a new human coronavirus: there and back again
# 2	62	Viral and Cellular mRNA Translation in Coronavirus-Infected Cells
# 2	63	Comparison of the S genes and the biological properties of respiratory and enteropathogenic bovine coronaviruses Brief Report
# 2	64	Reversal of the Progression of Fatal Coronavirus Infection in Cats by a Broad- Spectrum Coronavirus Protease Inhibitor
# 2	65	Recombination in Avian Gamma-Coronavirus Infectious Bronchitis Virus
# 2	66	Structural basis for human coronavirus attachment to sialic acid receptors HHS Public Access Author manuscript
# 2	67	Virus Research Molecular characterization of the S proteins of two enterotropic murine coronavirus strains
# 2	68	Murine encephalitis caused by HCoV-OC43, a human coronavirus with broad species specificity, is partly immune-mediated
# 2	69	Severe acute respiratory syndrome-related coronavirus: The species and its viruses -a statement of the Coronavirus Study Group
# 2	70	Characterizations of Coronavirus cis-Acting RNA Elements and the Transcription Step Affecting Its Transcription Efficiency
# 2	71	SARS associated coronavirus has a recombinant polymerase and coronaviruses have a history of host-shifting
# 2	72	Selection of and recombination between minor variants lead to the adaptation of an avian coronavirus to primate cells
# 2	73	Decline of transmissible gastroenteritis virus and its complex evolutionary relationship with porcine respiratory coronavirus in the United states
# 2	74	Viral and Cellular mRNA Translation in Coronavirus- Infected Cells
# 2	75	Inferring the hosts of coronavirus using dual statistical models based on nucleotide composition OPEN
# 2	76	Intestinal replication of a porcine respiratory coronavirus closely related antigenically to the enteric transmissible gastroenteritis virus
# 2	77	Potential for global spread of a novel coronavirus from China
# 2	78	Applying lessons from SARS to a newly identifi ed coronavirus
# 2	79	BMC Infectious Diseases Date of origin of the SARS coronavirus strains
# 2	80	Bovine coronaviruses associated with enteric and respiratory diseases in Canadian dairy cattle display different reactivities to anti-HE monoclonal antibodies and distinct amino acid changes in their HE, S and ns4.9 protein 7 0 2 ( 0 1 ) 0 0 2 4 3 -X
# 2	81	Consensus statement The species Severe acute respiratory syndrome- related coronavirus: classifying 2019-nCoV and naming it SARS-CoV-2 Coronaviridae Study Group of the International Committee on Taxonomy of Viruses*
# 2	82	MINIREVIEW Coronavirus Spike Proteins in Viral Entry and Pathogenesis
# 2	83	TWIRLS, an automated topic-wise inference method based on massive literature, suggests a possible mechanism via ACE2 for the pathological changes in the human host after coronavirus infection
# 2	84	Global Climate Changes and International Trade and Travel: Effects on Human Health Outcomes
# 2	85	Virus-based vectors for gene expression in mammalian cells: Coronavirus
# 2	86
# 2	87	TWIRLS, an automated topic-wise inference method based on massive literature, suggests a possible mechanism via ACE2 for the pathological changes in the human host after coronavirus infection
# 2	88	Cellular composition, coronavirus antigen expression and production of specific antibodies in lesions in feline infectious peritonitis
# 2	89	Proteomics analysis of differentially expressed proteins in chicken trachea and kidney after infection with the highly virulent and attenuated coronavirus infectious bronchitis virus in vivo
# 2	90	Springer Seminars in Immunopathology Immunopathological aspects of coronavirus infections
# 2	91	The human coronavirus HCoV-229E S-protein structure and receptor binding
# 2	92	The aetiology of SARS: Koch's postulates fulfilled
# 2	93	SARS-coronavirus replicates in mononuclear cells of peripheral blood (PBMCs) from SARS patients
# 2	94
# 2	95	Canine respiratory coronavirus employs caveolin-1-mediated pathway for internalization to HRT-18G cells
# 2	96	Molecular and phylogenetic analysis of bovine coronavirus based on the spike glycoprotein gene
# 2	97	Directional and reoccurring sequence change in zoonotic RNA virus genomes visualized by time- series word count OPEN
# 2	98	Serological Responses in Patients with Severe Acute Respiratory Syndrome Coronavirus Infection and Cross-Reactivity with Human Coronaviruses 229E, OC43, and NL63
# 2	99	STUDIES WITH AN UNCLASSIFIED VIRUS ISOLATED FROM DIARRHEIC CALVES
# 2	100	Vaccines for emerging infectious diseases: Lessons from MERS coronavirus and Zika virus
# 3	1	SARS CORONAVIRUS AND INNATE IMMUNITY
# 3	2	SARS coronavirus and innate immunity
# 3	3	Title: Candidate targets for immune responses to 2019-Novel Coronavirus (nCoV): sequence homology-and bioinformatic-based predictions
# 3	4	Coronavirus membrane-associated papain-like proteases induce autophagy through interacting with Beclin1 to negatively regulate antiviral innate immunity
# 3	5	Toll-Like Receptor 3 Signaling via TRIF Contributes to a Protective Innate Immune Response to Severe Acute Respiratory Syndrome Coronavirus Infection
# 3	6	Identification of a Gamma Interferon-Activated Inhibitor of Translation-Like RNA Motif at the 3= End of the Transmissible Gastroenteritis Coronavirus Genome Modulating Innate Immune Response
# 3	7	The Immunity Induced by Recombinant Spike Proteins of SARS Coronavirus in Balb/c Mice
# 3	8	The Conserved Coronavirus Macrodomain Promotes Virulence and Suppresses the Innate Immune Response during Severe Acute Respiratory Syndrome Coronavirus Infection
# 3	9	Projecting the transmission dynamics of SARS-CoV-2 through the post-pandemic period
# 3	10	Molecular pathology of emerging coronavirus infections
# 3	11	pathogens Epigenetic Landscape during Coronavirus Infection
# 3	12	Vulnerabilities in coronavirus glycan shields despite extensive glycosylation
# 3	13	A Sequence Homology and Bioinformatic Approach Can Predict Candidate Targets for Immune Responses to SARS-CoV-2 Theory A Sequence Homology and Bioinformatic Approach Can Predict Candidate Targets for Immune Responses to SARS-CoV-2
# 3	14	Medical Microbiology and Immunology Reactivity of Antibodies in Human Serum with Antigens of an Enteropathogenic Bovine Coronavirus
# 3	15	Dendritic Cell-Specific Antigen Delivery by Coronavirus Vaccine Vectors Induces Long-Lasting Protective Antiviral and Antitumor Immunity
# 3	16	T-cell immunity of SARS-CoV: Implications for vaccine development against MERS-CoV
# 3	17
# 3	18	Perspectives on the epizootiology of feline enteric coronavirus and the pathogenesis of feline infectious peritonitis
# 3	19	CD8+ T Cells Responding to the Middle East Respiratory Syndrome Coronavirus Nucleocapsid Protein Delivered by Vaccinia Virus MVA in Mice
# 3	20	Human CD4 + memory T-lymphocyte responses to SARS coronavirus infection
# 3	21	Early endonuclease-mediated evasion of RNA sensing ensures efficient coronavirus replication
# 3	22	Natural Infection with the Porcine Respiratory Coronavirus Induces Protective Lactogenic Immunity against Transmissible Gastroenteritis
# 3	23	Biomedical Science Review SARS Virus: The Beginning of the Unraveling of a New Coronavirus
# 3	24	Murine Coronavirus-Induced Encephalomyelitides in Rats: Analysis of Immunoglobulins and Virus-Specific Antibodies in Serum and Cerebrospinal Fluid
# 3	25	Reversal of the Progression of Fatal Coronavirus Infection in Cats by a Broad- Spectrum Coronavirus Protease Inhibitor
# 3	26	European Journal of Case Reports in Internal Medicine Severe Immune Thrombocytopenia Complicated by Intracerebral Haemorrhage Associated with Coronavirus Infection: A Case Report and Literature Review
# 3	27	Identification of murine CD8 T cell epitopes in codon-optimized SARS-associated coronavirus spike protein
# 3	28	Cryo-electron microscopy structure of the SADS-CoV spike glycoprotein 1 provides insights into an evolution of unique coronavirus spike proteins 2 3
# 3	29	Selective Packaging in Murine Coronavirus Promotes Virulence by Limiting Type I Interferon Responses
# 3	30	Interferon and cytokine responses to SARS-coronavirus infection
# 3	31	Immune evasion of porcine enteric coronaviruses and viral modulation of antiviral innate signaling
# 3	32	Enteric Viral Infections of Calves and Passive Immunity 1
# 3	33	Intragastric administration of Lactobacillus casei expressing transmissible gastroentritis coronavirus spike glycoprotein induced specific antibody production
# 3	34	Assembly and immunogenicity of coronavirus-like particles carrying infectious bronchitis virus M and S proteins
# 3	35	Antagonism of dsRNA-Induced Innate Immune Pathways by NS4a and NS4b Accessory Proteins during MERS Coronavirus Infection
# 3	36	A genome-wide association study identifies major loci affecting the immune response against infectious bronchitis virus in chicken
# 3	37	Dendritic Cell-Specific Delivery of Flt3L by Coronavirus Vectors Secures Induction of Therapeutic Antitumor Immunity
# 3	38
# 3	39	Protection from Lethal Coronavirus Infection by Affinity-Purified Spike Glycoprotein of Murine Hepatitis Virus, Strain A59
# 3	40	Expression profiles of immune mediators in feline Coronavirus-infected cells and clinical samples of feline Coronavirus-positive cats
# 3	41	Transmissible Gastroenteritis Virus Papain-Like Protease 1 Antagonizes Production of Interferon-through Its Deubiquitinase Activity
# 3	42	University of North Carolina at Chapel Hill, Chapel Hill, NC, and accepted by Editorial Board Member Linda J
# 3	43	Attempted immunisation of cats against feline infectlous peritonitis using canine coronavirus
# 3	44	Archives of Virology Studies on the Relationship Between Coronaviruses from the Intestinal and Respiratory Tracts oi Calves
# 3	45	Transmissible gastroenteritis virus (TGEV)-based vectors with engineered murine tropism express the rotavirus VP7 protein and immunize mice against rotavirus
# 3	46	Correspondence
# 3	47	Ferret Coronavirus- Associated Diseases
# 3	48	RAT CORONAVIRUS
# 3	49
# 3	50	Superior immune responses induced by intranasal immunization with recombinant adenovirus-based vaccine expressing full- length Spike protein of Middle East respiratory syndrome coronavirus
# 3	51	The immune vulnerability landscape of the 2019 Novel Coronavirus, SARS- CoV-2
# 3	52	Structural insights into the Middle East respiratory syndrome coronavirus 4a protein and its dsRNA binding mechanism OPEN
# 3	53	Coronavirus-induced ER stress response and its involvement in regulation of coronavirus-host interactions
# 3	54	Molecular characterization of a virulent canine coronavirus BGF strain ଝ
# 3	55	Short Communication
# 3	56	Intestinal protection against challenge with transmissible gastroenteritis virus of pigs immune after infection with the porcine respiratory coronavirus
# 3	57	Unlocking bat immunology: establishment of Pteropus alecto bone marrow-derived dendritic cells and macrophages OPEN
# 3	58	LY6E impairs coronavirus fusion and confers immune control of viral disease
# 3	59	Complement Activation Contributes to Severe Acute Respiratory Syndrome Coronavirus Pathogenesis
# 3	60	Immunogenicity of an adenoviral-based Middle East Respiratory Syndrome coronavirus vaccine in BALB/c mice
# 3	61	Antibody-dependent infection of human macrophages by severe acute respiratory syndrome coronavirus
# 3	62	Excretion and persistence of bovine coronavirus in neonatal calves Brief Report
# 3	63	Orchitis in a Cat Associated with Coronavirus Infection
# 3	64	A Novel Bacterium-Like Particle Vaccine Displaying the MERS-CoV Receptor-Binding Domain Induces Specific Mucosal and Systemic Immune Responses in Mice
# 3	65
# 3	66	Middle East Respiratory Syndrome Coronavirus NS4b Protein Inhibits Host RNase L Activation
# 3	67	Molecular mechanisms of coronavirus RNA capping and methylation
# 3	68	Antibodies against trimeric S glycoprotein protect hamsters against SARS-CoV challenge despite their capacity to mediate Fc␥RII-dependent entry into B cells in vitro
# 3	69
# 3	70	Augmentation of immune responses to SARS coronavirus by a combination of DNA and whole killed virus vaccines
# 3	71	Coronavirus immunogens
# 3	72	Detection of an Antigenic Group 2 Coronavirus in an Adult Alpaca with Enteritis ᰔ Downloaded from
# 3	73	Detection of an Antigenic Group 2 Coronavirus in an Adult Alpaca with Enteritis ᰔ Downloaded from
# 3	74	SARS coronavirus pathogenesis: host innate immune responses and viral antagonism of interferon
# 3	75	Protection from SARS coronavirus conferred by live measles vaccine expressing the spike glycoprotein
# 3	76
# 3	77	Intranasal immunization with inactivated SARS-CoV (SARS-associated coronavirus) induced local and serum antibodies in mice
# 3	78	Induction of lactogenic immunity to transmissible gastroenteritis virus of swine using an attenuated coronavirus mutant able to survive in the physicochemical environment of the digestive tract
# 3	79
# 3	80	DNA vaccine encoding Middle East respiratory syndrome coronavirus S1 protein induces protective immune responses in mice
# 3	81	Glucose-6-Phosphate Dehydrogenase Enhances Antiviral Response through Downregulation of NADPH Sensor HSCARG and Upregulation of NF-κB Signaling
# 3	82	Molecular targets for the rational design of drugs to inhibit SARS coronavirus
# 3	83	Enteric Viral Infections of Pigs and Strategies for Induction of Mucosal Immunity
# 3	84	DNA Vaccine Encoding Middle East Respiratory Syndrome Coronavirus S1 Protein Induces Protective Immune Responses in Mice HHS Public Access
# 3	85	Immunogenicity, safety, and protective efficacy of an inactivated SARS-associated coronavirus vaccine in rhesus monkeys
# 3	86	Swine acute diarrhea syndrome coronavirus (SADS-CoV) antagonizes interferon-β production via blocking IPS-1 and RIG-I
# 3	87	Molecular mechanisms of primary and secondary mucosal immunity using avian infectious bronchitis virus as a model system
# 3	88	Sublingual immunization with recombinant adenovirus encoding SARS-CoV spike protein induces systemic and mucosal immunity without redirection of the virus to the brain
# 3	89	Induction of Specific Immune Responses by Severe Acute Respiratory Syndrome Coronavirus Spike DNA Vaccine with or without Interleukin-2 Immunization Using Different Vaccination Routes in Mice ᰔ
# 3	90	MERS-CoV 4b protein interferes with the NF- κB-dependent innate immune response during infection Author summary
# 3	91	SARS-CoV Regulates Immune Function-Related Gene Expression in Human Monocytic Cells
# 3	92
# 3	93	Enhanced protection in mice induced by immunization with inactivated whole viruses compare to spike protein of middle east respiratory syndrome coronavirus
# 3	94	Human β-defensin 2 plays a regulatory role in innate antiviral immunity and is capable of potentiating the induction of antigen- specific immunity
# 3	95	Protective Role of Toll-like Receptor 3-Induced Type I Interferon in Murine Coronavirus Infection of Macrophages
# 3	96	Treatment of cats with feline infectious peritonitis
# 3	97
# 3	98	Development of a Western Blot Assay for Detection of Antibodies against Coronavirus Causing Severe Acute Respiratory Syndrome
# 3	99	Adenoviral expression of a truncated S1 subunit of SARS-CoV spike protein results in specific humoral immune responses against SARS-CoV in rats
# 3	100	Virus-based vectors for gene expression in mammalian cells: Coronavirus

# %% [markdown]
# ##Here we do the query for:
# 1. Korea
# 2. WHO
# 3. Hospital
# 4. recovered

# %%
q1 = ['Korea', 'WHO', 'Hospital', 'recovered']
retrieve(q1)
# Out:
# 1	1	Costly Lessons From the 2015 Middle East Respiratory Syndrome Coronavirus Outbreak in Korea
# 1	2	Disasters can happen to anybody: The case of Korea
# 1	3	Fatality risks for nosocomial outbreaks of Middle East respiratory syndrome coronavirus in the Middle East and South Korea
# 1	4	How to Manage a Public Health Crisis and Bioterrorism in Korea
# 1	5	New emergence pattern with variant porcine epidemic diarrhea viruses, South Korea, 2012-2015
# 1	6	Examining professional emergency managers in Korea
# 1	7	Epidemic Intelligence Service Officers and Field Epidemiology Training Program in Korea
# 1	8	Recent increase of surface particulate matter concentrations in the Seoul Metropolitan Area, Korea OPEN
# 1	9	Preliminary estimating the reproduction number of the coronavirus disease (COVID-19) outbreak in Republic of Korea and Italy by 5 March 2020
# 1	10	Lessons drawn from China and South Korea for managing COVID-19 epidemic: insights from a comparative modeling study
# 1	11	Publication of the Korea-WHO Cooperation History -70 Years of Working Together for Heath: World Health Organization and the Republic of Korea
# 1	12	Estimation of basic reproduction number of the Middle East respiratory syndrome coronavirus (MERS-CoV) during the outbreak in South Korea, 2015
# 1	13	Journal Pre-proof Transmission potential and severity of COVID-19 in South Korea Title: Transmission potential and severity of COVID-19 in South Korea
# 1	14	Spatial Visualization of Cluster-Specific COVID-19 Transmission Network in South Korea During the Early Epidemic Phase
# 1	15	Factors Influencing the Response to Infectious Diseases: Focusing on the Case of SARS and MERS in South Korea
# 1	16	Stochastic and spatio-temporal analysis of the Middle East Respiratory Syndrome outbreak in South Korea, 2015-NC-ND license (http://creativecommons.org/licenses/by-nc-nd/4.0/)
# 1	17	Stochastic and spatio-temporal analysis of the Middle East Respiratory Syndrome outbreak in South Korea, 2015-NC-ND license (http://creativecommons.org/licenses/by-nc-nd/4.0/)
# 1	18	Public Health Crisis Preparedness and Response in Korea
# 1	19	Public Health Crisis Preparedness and Response in Korea
# 1	20	Enhancing Laboratory Response Network Capacity in South Korea
# 1	21	Title: Transmission potential of COVID-19 in South Korea
# 1	22	Ethical Perspectives on the Middle East Respiratory Syndrome Coronavirus Epidemic in Korea
# 1	23	Strengthening epidemiologic investigation of infectious diseases in Korea: lessons from the Middle East Respiratory Syndrome outbreak
# 1	24	Complete Genome Sequence of Human Coronavirus NL63 CN0601/14, First Isolated in South Korea
# 1	25	The Effect of Having a Regular Doctor as a Primary Care Provider on Emergency Room Utilization in South Korea The Effect of Having a Regular Doctor on Emergency Room Utilization
# 1	26	Factors Affecting the Disaster Response Competency of Emergency Medical Technicians in South Korea
# 1	27	Importation of travel-related infectious diseases is increasing in South Korea: An analysis of salmonellosis, shigellosis, malaria, and dengue surveillance data
# 1	28	Investigation of nonlinear epidemiological models for analyzing and controlling the MERS outbreak in Korea
# 1	29	Molecular epidemiology and phylogenetic analysis of porcine epidemic diarrhea virus (PEDV) field isolates in Korea
# 1	30	Distributed under Creative Commons CC-BY 4.0 OPEN ACCESS 2015 Middle East Respiratory Syndrome Coronavirus (MERS-CoV) nosocomial outbreak in South Korea: insights from modeling
# 1	31	Estimating the risk of Middle East respiratory syndrome (MERS) death during the course of the outbreak in the Republic of Korea, 2015
# 1	32	Middle East respiratory syndrome risk perception among students at a university in South Korea, 2015
# 1	33	Phylogenetic analysis of porcine astrovirus in domestic pigs and wild boars in South Korea
# 1	34	Complete genome sequence of K14JB01, a novel variant strain of porcine epidemic diarrhea virus in South Korea
# 1	35	EPIDEMIOLOGIC INVESTIGATION Healthcare worker infected with Middle East Respiratory Syndrome during cardiopulmonary resuscitation in Korea, 2015
# 1	36	Better Understanding on MERS Corona Virus Outbreak in Korea
# 1	37	The changes of prevalence and etiology of pediatric pneumonia from National Emergency Department Information System in Korea, between 2007 and 2014
# 1	38	SEARCH STRATEGY PubMed databases were searched for studies on MERS cases during the 2015 outbreak in the Republic of Korea. The search terms used were combinations of 'Middle East respiratory syndrome' in all fields and 'Korea' in all
# 1	39	Genetic Diversity of Spike, 3a, 3b and E Genes of Infectious Bronchitis Viruses and Emergence of New Recombinants in Korea
# 1	40	Worry experienced during the 2015 Middle East Respiratory Syndrome (MERS) pandemic in Korea
# 1	41	Experience of 16 years and its associated challenges in the Field Epidemiology Training Program in Korea Current states, past experiences, and achievements of KFETP Selection of field epidemiologists
# 1	42	Factors influencing preventive behavior against Middle East Respiratory Syndrome-Coronavirus among nursing students in South Korea ☆
# 1	43	Comparison of incubation period distribution of human infections with MERS-CoV in South Korea and Saudi Arabia
# 1	44	Full-Genome Sequence Analysis of a Variant Strain of Porcine Epidemic Diarrhea Virus in South Korea
# 1	45	Bacterial and Viral Identification Rate in Acute Exacerbation of Chronic Obstructive Pulmonary Disease in Korea
# 1	46	Multilocus typing of Cryptosporidium spp. in young calves with diarrhea in Korea
# 1	47	Current Status of Infection Prevention and Control Programs for Emergency Medical Personnel in the Republic of Korea
# 1	48	Heterogeneity in spike protein genes of porcine epidemic diarrhea viruses isolated in Korea
# 1	49	Decentralization and collaborative disaster governance: Evidence from South Korea
# 1	50	The effects of past SARS experience and proximity on declines in numbers of travelers to the Republic of Korea during the 2015 MERS outbreak: A retrospective study
# 1	51	The clinical and virological features of the first imported case causing MERS-CoV outbreak in South Korea, 2015
# 1	52	Veterinary Science Molecular characterization and genogrouping of VP1 of aquatic birnavirus GC1 isolated from rockfish Sebastes schlegeli in Korea
# 1	53	High reproduction number of Middle East respiratory syndrome coronavirus in nosocomial outbreaks: mathematical modelling in Saudi Arabia and South Korea
# 1	54	Title: Basic and effective reproduction numbers of COVID-19 cases in South Korea excluding Sincheonji cases
# 1	55	A dynamic compartmental model for the Middle East respiratory syndrome outbreak in the Republic of Korea: A retrospective analysis on control interventions and superspreading events-NC-ND license (http://creativecommons.org/licenses/by-nc-nd/4.0/)
# 1	56	Prediction of COVID-19 Spreading Profiles in South Korea, Italy and Iran by Data-Driven Coding
# 1	57	Modeling the Transmission of Middle East Respirator Syndrome Corona Virus in the Republic of Korea
# 1	58	Ethics statement EPIDEMIOLOGICAL CHARACTERISTICS Causes and countermeasures for repeated outbreaks of hepatitis A among adults in Korea
# 1	59	Comparative analysis on the 5 0 -untranslated region of bovine viral diarrhea virus isolated in Korea
# 1	60	Improved survival rates in patients with H1N1 acute respiratory failure in Korea between 2009 and 2016
# 1	61	Crisis prevention and management by infection control nurses during the Middle East respiratory coronavirus outbreak in Korea American Journal of Infection Control
# 1	62	Seroprevalence of Respiratory Syncytial Virus IgG among Healthy Young Adults in Basic Training for the Republic of Korea Air Force
# 1	63	Incidence and Mortality Rates of Disasters and Mass Casualty Incidents in Korea: A Population-Based Cross-Sectional Study
# 1	64	Exploring the Determinants of Perceived Risk of Middle East Respiratory Syndrome (MERS) in Korea
# 1	65	The effects of SNS communication: How expressing and receiving information predict MERS-preventive behavioral intentions in South Korea
# 1	66	Genetic characterization of porcine epidemic diarrhea virus in Korea from 1998 to 2013
# 1	67	Molecular epidemiology of bovine noroviruses in South Korea
# 1	68	Molecular detection and characterization of unclassified bovine enteric caliciviruses in South Korea
# 1	69	Middle East Respiratory Syndrome Coronavirus Outbreak in the Republic of Korea, 2015 Korea Centers for Disease Control and Prevention*
# 1	70	Middle East Respiratory Syndrome Coronavirus Outbreak in the Republic of Korea, 2015 Korea Centers for Disease Control and Prevention*
# 1	71	Isolation and characterization of a new porcine epidemic diarrhea virus variant that occurred in Korea in 2014
# 1	72	| Division of International Cooperation, Ministry of Health and Welfare, Sejong, Republic of Korea. b Country Support Unit, World Health Organization Regional Offi ce for the Western Pacifi c
# 1	73	Epidemiological Characteristics of Imported Influenza A (H1N1) Cases during the 2009 Pandemic in Korea
# 1	74	Molecular analysis of S gene of spike glycoprotein of winter dysentery bovine coronavirus circulated in Korea during 2002-2003
# 1	75	Experience with intravenous ribavirin in the treatment of hemorrhagic fever with renal syndrome in Korea ଝ
# 1	76	An emerging recombinant cluster of nephropathogenic strains of avian infectious bronchitis virus in Korea
# 1	77	Changes in clinical and laboratory features of Kawasaki disease noted over time in Daejeon, Korea
# 1	78	CASE STUDY System effectiveness of detection, brief intervention and refer to treatment for the people with post-traumatic emotional distress by MERS: a case report of community-based proactive intervention in South Korea
# 1	79	Physica A The daily computed weighted averaging basic reproduction number R n 0,k,ω for MERS-CoV in South Korea
# 1	80	Seasonal trends of diagnosis of childhood malignant diseases and viral prevalence in South Korea
# 1	81	Open Access Fever Screening and Detection of Febrile Arrivals at an International Airport in Korea: Association among Self-reported Fever, Infrared Thermal Camera Scanning, and Tympanic Temperature
# 1	82	Comparative genomics of QX-like infectious bronchitis viruses in Korea
# 1	83	EPIDEMIOLOGIC INVESTIGATION Epidemiological investigation of the 119th confirmed Middle East Respiratory Syndrome coronavirus case with an indefinite mode of transmission during the Pyeongtaek outbreak in Korea
# 1	84	Structural Factors of the Middle East Respiratory Syndrome Coronavirus Outbreak as a Public Health Crisis in Korea and Future Response Strategies
# 1	85	Effects of operational decisions on the diffusion of epidemic disease: A system dynamics modeling of the MERS-CoV outbreak in South Korea
# 1	86	ISDS 2018 Conference Abstracts A provincial Acute Febrile Illness Surveillance Network (GAFINet), South Korea
# 1	87	Surveillance and public health response for travelers returning from MERS-CoV affected countries to Gyeonggi Province, Korea, 2016-2017
# 1	88	viruses A Comparative Analysis of Factors Influencing Two Outbreaks of Middle Eastern Respiratory Syndrome (MERS) in Saudi Arabia and South Korea
# 1	89	National post-market surveillance assessment of veterinary medicines in Korea during the past decade
# 1	90	Temporal relationship between antibiotic use and respiratory virus activities in the Republic of Korea: a time-series analysis
# 1	91	Chest Radiographic and CT Findings of the 2019 Novel Coronavirus Disease (COVID-19): Analysis of Nine Patients Treated in Korea
# 1	92	Urgent Call for Research on Middle East Respiratory Syndrome (MERS) in Korea Editorial
# 1	93	Asymptomatic Middle East Respiratory Syndrome coronavirus infection using a serologic survey in Korea
# 1	94	Comparison of the coronavirus pandemic dynamics in Europe, USA and South Korea
# 1	95	Sequential Emergence and Wide Spread of Neutralization Escape Middle East Respiratory Syndrome Coronavirus Mutants, South Korea, 2015
# 1	96	A Comparison of the Clinical and Epidemiological Characteristics of Adult Patients with Laboratory- Confirmed Influenza A or B during the 2011-2012 Influenza Season in Korea: A Multi-Center Study
# 1	97	Outbreak of Middle East Respiratory Syndrome in Korea?
# 1	98	LETTERS Isolation of Porcine Epidemic Diarrhea Virus during Outbreaks in South Korea, 2013-2014
# 1	99	Role of tourism price in attracting international tourists: The case of Japanese inbound tourism from South Korea
# 1	100	Changes in infection control policies and advancing infection control advanced practice nurse education in the Republic of Korea
# 2	1
# 2	2
# 2	3
# 2	4
# 2	5
# 2	6
# 2	7
# 2	8
# 2	9
# 2	10
# 2	11
# 2	12
# 2	13
# 2	14
# 2	15
# 2	16
# 2	17
# 2	18
# 2	19
# 2	20
# 2	21
# 2	22
# 2	23
# 2	24
# 2	25
# 2	26
# 2	27
# 2	28
# 2	29
# 2	30
# 2	31
# 2	32
# 2	33
# 2	34
# 2	35
# 2	36
# 2	37
# 2	38
# 2	39
# 2	40
# 2	41
# 2	42
# 2	43
# 2	44
# 2	45
# 2	46
# 2	47
# 2	48
# 2	49
# 2	50
# 2	51
# 2	52
# 2	53
# 2	54
# 2	55
# 2	56
# 2	57
# 2	58
# 2	59
# 2	60
# 2	61
# 2	62
# 2	63
# 2	64
# 2	65
# 2	66
# 2	67
# 2	68
# 2	69
# 2	70
# 2	71
# 2	72
# 2	73
# 2	74
# 2	75
# 2	76
# 2	77
# 2	78
# 2	79
# 2	80
# 2	81
# 2	82
# 2	83
# 2	84
# 2	85
# 2	86
# 2	87
# 2	88
# 2	89
# 2	90
# 2	91
# 2	92
# 2	93
# 2	94
# 2	95
# 2	96
# 2	97
# 2	98
# 2	99
# 2	100
# 3	1	Effect of proactive infection control measures on benchmarked rate of hospital outbreaks: An analysis of public hospitals in Hong Kong over 5 years
# 3	2	Fact-fi nding survey of nosocomial infection control in hospitals in Vietnam and application to training programs
# 3	3	The Role of Hospitals in Disaster
# 3	4	Limiting the spread of highly resistant hospital-acquired microorganisms via critical care transfers: a simulation study
# 3	5	Syndromic Surveillance: Hospital Emergency Department Participation During the Kentucky Derby Festival
# 3	6	Inpatient Capacity at Children's Hospitals during Pandemic (H1N1) 2009 Outbreak, United States
# 3	7	An analysis of the current status of hospital emergency preparedness for infectious disease outbreaks in Beijing, China
# 3	8	Community -and hospital laboratory-based surveillance for respiratory viruses
# 3	9	Emergency Department Response to SARS, Taiwan Emergency Department Response to SARS, Taiwan Emerging Infectious Diseases • www Past Issues on SARS
# 3	10	Barriers to implementing antimicrobial stewardship programmes in three Saudi hospitals: Evidence from a qualitative study
# 3	11
# 3	12	Survey of influenza and other respiratory viruses diagnostic testing in US hospitals, 2012-2013
# 3	13	A comparison of infection control program resources, activities, and antibiotic resistant organism rates in Canadian acute care hospitals in 1999 and 2005: Pre-and post-severe acute respiratory syndrome
# 3	14	WHAT MAKES HOSPITALIZATION SYSTEM MORE EFFICIENT? AN APPLICATION OF THE DECOMPOSITION METHOD TO HONG KONG MORBIDITY DATA TITLE: WHAT MAKES HOSPITALIZATION SYSTEM MORE EFFICIENT? AN APPLICATION OF THE DECOMPOSITION METHOD TO HONG KONG MORBIDITY DATA
# 3	15	Disaster resilience in tertiary hospitals: a cross-sectional survey in Shandong Province, China
# 3	16
# 3	17	Hospital incident command system (HICS) performance in Iran; decision making during disasters
# 3	18	Factors affecting cross-hospital exchange of Electronic Medical Records
# 3	19	Daejeon Provincial Government
# 3	20	Processes of care for community-acquired pneumonia
# 3	21
# 3	22	Knowledge and attitude of healthcare workers and patients on healthcare associated infections in a regional hospital in Ghana Asian Pacific Journal of Tropical Disease
# 3	23	A cross-sectional study of the clinical characteristics of hospitalized children with community-acquired pneumonia in eight eastern cities in China
# 3	24	The impact on neonatal mortality of shifting childbirth services among levels of hospitals: Taiwan's experience
# 3	25
# 3	26
# 3	27	Journal Pre-proof The Preventive Strategies of Community Hospital in the Battle of Fighting Pandemic COVID-19 in Taiwan
# 3	28
# 3	29	Setting healthcare priorities in hospitals: a review of empirical studies
# 3	30	Application of WHO's guideline for the selection of sentinel sites for hospital-based influenza surveillance in Indonesia
# 3	31	Intervals Before Tuberculosis Diagnosis and Isolation at a Regional Hospital in Taiwan
# 3	32	The Risk and Prevention of Novel Coronavirus Pneumonia Infections Among Inpatients in Psychiatric Hospitals
# 3	33	The pandemic influenza planning process in Ontario acute care hospitals
# 3	34	Hospital-Acquired Respiratory Viral Infections: Incidence, Morbidity, and Mortality in Pediatric and Adult Patients
# 3	35	Barrier precautions, isolation protocols, and personal hygiene in veterinary hospitals
# 3	36
# 3	37	Journal Pre-proof Kidney disease is associated with in-hospital death of patients with COVID-19 Kidney disease is associated with in-hospital death of patients with COVID-19
# 3	38	Rates of respiratory virus-associated hospitalization in children aged <5 years in rural northern India
# 3	39	The study on the outsourcing of Taiwan's hospitals: a questionnaire survey research
# 3	40	Preparedness of Hospitals in the Republic of Ireland for an Influenza Pandemic, an Infection Control Perspective
# 3	41	The impact of influenza and respiratory syncytial virus on hospitalizations for lower respiratory tract infections in young children: Slovenia, 2006-2011
# 3	42	Rapid Response Systems Reduce In-Hospital Cardiopulmonary Arrest: A Pilot Study and Motivation for a Nationwide Survey
# 3	43	Estimating the burden of influenza-associated hospitalization and deaths in Oman (2012-2015) Background: Influenza is a serious vaccine-preventable disease with high incidence
# 3	44	HOSPITAL-ACQUIRED SARS IN TAIPEI, TAIWAN ORIGINAL ARTICLE
# 3	45	SARS Transmission among Hospital Workers in Hong Kong EMERGENCE OF SARS
# 3	46
# 3	47	Current status of personnel and infrastructure resources for infection prevention and control programs in the Republic of Korea: A national survey
# 3	48	Pandemic Infl uenza and Hospital Resources
# 3	49	Burden, spectrum, and impact of healthcare-associated infection at a South African children's hospital
# 3	50
# 3	51	Microsimulation of Financial Impact of Demand Surge on Hospitals: The H1N1 Influenza Pandemic of Fall 2009 Health Services Research
# 3	52
# 3	53
# 3	54
# 3	55	"Differential risk of hospitalization among single virus infections causing influenza-like illnesses" Background: Acute respiratory infections are a major cause of morbidity in children
# 3	56	Emergency Preparedness and the Development of Health Care Coalitions A Dynamic Process
# 3	57	A retrospective analysis assessing the spatial and temporal distribution of pediatric acute respiratory tract infections in A retrospective analysis assessing the spatial and temporal distribution of pediatric acute 1 respiratory tract infections in
# 3	58	The effect of regionalization on outcome in pulmonary lobectomy: A Canadian national study
# 3	59	Acute care utilization due to hospitalizations for pediatric lower respiratory tract infections in British Columbia, Canada
# 3	60	Kaohsiung Armed Forces General Hospital Gangshan Branch, Taiwan, ROC d Department of Nursing, Tri-Service General Hospital, National Defence Medical Centre, Taiwan (ROC) No. 325, Sec. 2, Cheng-gong Rd
# 3	61	Perception and Performance of Preventive Behaviors for the Pandemic Influenza in Hospital Employees and Outpatients
# 3	62	From the Ministry of Health
# 3	63	Kidney impairment is associated with in-hospital death of COVID- 19 patients
# 3	64	Comparison of the prevalence of respiratory viruses in patients with acute respiratory infections at different hospital settings in North China, 2012-2015
# 3	65	Family caregivers in public tertiary care hospitals in Bangladesh: Risks and opportunities for infection control
# 3	66	Hospitalized adult patients with 2009 influenza A (H1N1) in Beijing, China: risk factors for hospital mortality
# 3	67	Fact-finding Survey of Nosocomial Infection Control in Hospitals in Kathmandu, Nepal-A Basis for Improvement
# 3	68
# 3	69	PEER REVIEW HISTORY
# 3	70
# 3	71	A Generalized Discrete Dynamic Model for Human Epidemics
# 3	72	C L I N I C A L 218 JOURNAL OF EMERGENCY NURSING
# 3	73	Lessons from a one-year hospital-based surveillance of acute respiratory infections in Berlin-comparing case definitions to monitor influenza
# 3	74	Psychiatric symptoms and psychosocial functioning among hospital personnel during the Gaza War: A repeated cross-sectional study
# 3	75	INQUIRY: The Journal of Health Care Organization, Provision, and Financing
# 3	76	High incidence of viral co-infections and atypical bacterial detection in acute respiratory infections among hospitalized children in the Central Department of Paraguay, 2010e2011
# 3	77	Has the medical reform improved the cost efficiency of Chinese hospitals?
# 3	78	Clinical Commentary iII CHEST Uncharted Paths· Hospital Networks in Critical Care
# 3	79	Assistant Professor of Internal Medicine, Pulmonary & Critical Care Medicine, 3A23 300 NIB, SPC 5419, 300 North Ingalls
# 3	80	Major reduction of rotavirus, but not norovirus, gastroenteritis in children seen in hospital after the introduction of RotaTeq vaccine into the National Immunization Programme in Finland
# 3	81
# 3	82	Crisis prevention and management by infection control nurses during the Middle East respiratory coronavirus outbreak in Korea American Journal of Infection Control
# 3	83
# 3	84	Temporal Trends of In-Hospital Mortality in Patients Treated with Intra-Aortic Balloon Pumping: A Nationwide Population Study in Taiwan
# 3	85	Publication dates: Available online
# 3	86	Airflow analysis of Pyeongtaek St Mary's Hospital during hospitalization of the first Middle East respiratory syndrome patient in Korea
# 3	87	Parental Response to Child's Isolation During the SARS Outbreak
# 3	88	Factors associated with system-level activities for patient safety and infection control
# 3	89	The Effect of Hospital Isolation Precautions on Patient Outcomes and Cost of Care: A Multi-Site, Retrospective, Propensity Score-Matched Cohort Study
# 3	90
# 3	91	Additional file 1: Risk of MERS importation and onward transmission: a systematic review and analysis of cases reported to WHO
# 3	92	The Initial Hospital Response to an Epidemic
# 3	93	What makes the hospitalisation system more efficient? An application of the decomposition method to Hong Kong morbidity data
# 3	94	Early Intervention Can Improve Clinical Outcome of Acute Interstitial Pneumonia*
# 3	95	P a g e Screening and managing of suspected or confirmed novel coronavirus (COVID-19) patients: experiences from a tertiary hospital outside Hubei province
# 3	96	The Brazilian Journal of INFECTIOUS DISEASES Clinical relevance of rhinovirus infections among adult hospitalized patients
# 3	97	Molecular Distance to Health Transcriptional Score and Disease Severity in Children Hospitalized With Community-Acquired Pneumonia
# 3	98	Prevalence and contribution of respiratory viruses in the community to rates of emergency department visits and hospitalizations with respiratory tract infections, chronic obstructive pulmonary disease and asthma
# 3	99	The use of the temporal scan statistic to detect methicillin-resistant Staphylococcus aureus clusters in a community hospital
# 3	100	Feature Article
# 4	1	Lack of cross-protection against Mycoplasma haemofelis infection and signs of enhancement in "Candidatus Mycoplasma turicensis"-recovered cats
# 4	2	Long-Term Persistence of Robust Antibody and Cytotoxic T Cell Responses in Recovered Patients Infected with SARS Coronavirus
# 4	3	Characterization of SARS-CoV-specific memory T cells from recovered individuals 4 years after infection
# 4	4	FOCUSED REVIEW Recovering full-length viral genomes from metagenomes
# 4	5	Lau et al: Randomised trial of an exercise program for patients recovering from SARS A randomised controlled trial of the effectiveness of an exercise training program in patients recovering from severe acute respiratory syndrome
# 4	6	Potent and persistent antibody responses against the receptor-binding domain of SARS-CoV spike protein in recovered patients
# 4	7	Tachycardia amongst subjects recovering from severe acute respiratory syndrome (SARS)
# 4	8	Characterization of SARS-CoV-specific memory T cells from recovered individuals 4 years after infection HHS Public Access
# 4	9	Canine caliciviruses of four serotypes from military and research dogs recovered in 1963−1978 belong to two phylogenetic clades in the Vesivirus genus
# 4	10	Altered Lipid Metabolism in Recovered SARS Patients Twelve Years after Infection OPEN
# 4	11	Long-lived memory T lymphocyte responses against SARS coronavirus nucleocapsid protein in SARS-recovered patients
# 4	12	BMC Genomics Molecular signature of clinical severity in recovering patients with severe acute respiratory syndrome coronavirus (SARS-CoV)
# 4	13	Production of an Anti-Severe Acute Respiratory Syndrome (SARS) Coronavirus Human Monoclonal Antibody Fab Fragment by Using a Combinatorial Immunoglobulin Gene Library Derived from Patients Who Recovered from SARS
# 4	14	Production of an Anti-Severe Acute Respiratory Syndrome (SARS) Coronavirus Human Monoclonal Antibody Fab Fragment by Using a Combinatorial Immunoglobulin Gene Library Derived from Patients Who Recovered from SARS
# 4	15	Recovering from SARS: The Case of Toronto Tourism
# 4	16	Characterization of anti-viral immunity in recovered individuals infected by SARS-CoV-2
# 4	17	Respiratory Research Dynamic changes of serum SARS-Coronavirus IgG, pulmonary function and radiography in patients recovering from SARS after hospital discharge Severe acute respiratory syndrome (SARS)SARS-CoV IgG antibodyPulmonary functionPulmonary fibrosisAvascular necrosis of femoral head
# 4	18	The negative spillover effect of food crises on restaurant firms: Did Jack in the Box really recover from an E. coli scare?
# 4	19	Long-lived effector/central memory T-cell responses to severe acute respiratory syndrome coronavirus (SARS-CoV) S antigen in recovered SARS patients
# 4	20	Selective depletion of glycyrrhizin from Si-Ni-San, a traditional Chinese prescription, blocks its effect on contact sensitivity in mice and recovers adhesion and metalloproteinases production of T lymphocytes

# %% [markdown]
# ***

# %% [markdown]
# # References

# %% [markdown]
# [bm25 documentation](https://pypi.org/project/rank-bm25/)
#
# [sklearn TFidfTransformer documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html)
